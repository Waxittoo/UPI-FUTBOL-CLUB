-- %% [markdown]
-- # [dbo].[entrenador]

-- %%
USE [UHFC]
GO

-- %%
/****** Object:  Table [dbo].[entrenador]    Script Date: 3/18/2024 5:02:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[entrenador](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](50) NULL,
	[titulos] [varchar](150) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Jugador]

-- %%
/****** Object:  Table [dbo].[Jugador]    Script Date: 3/18/2024 5:02:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Jugador](
	[id] [int] NULL,
	[nombre] [varchar](50) NULL,
	[edad] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[entrenador]

-- %%
SET IDENTITY_INSERT [dbo].[entrenador] ON 
INSERT [dbo].[entrenador] ([id], [nombre], [titulos]) VALUES (1, N'Hernan Medfor', N'Sporting')
INSERT [dbo].[entrenador] ([id], [nombre], [titulos]) VALUES (2, N'Wilmer lopez', N'Alajuela')
INSERT [dbo].[entrenador] ([id], [nombre], [titulos]) VALUES (3, N'Wanchope', N'Cartaguito')
INSERT [dbo].[entrenador] ([id], [nombre], [titulos]) VALUES (4, N'Jafet Soto', N'Heredia')
INSERT [dbo].[entrenador] ([id], [nombre], [titulos]) VALUES (5, N'Vladimir ', N'Saprissa')
SET IDENTITY_INSERT [dbo].[entrenador] OFF
GO

-- %% [markdown]
-- # [dbo].[Jugador]

-- %%
INSERT [dbo].[Jugador] ([id], [nombre], [edad]) VALUES (2, N'Douglas sequera', 20)
GO
